# %%
import pandas as pd
data=pd.read_csv('ifood_df.csv')
data.head()
# Out:
#     Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0  58138.0        0         0       58       635         88              546
# 1  46344.0        1         1       38        11          1                6
# 2  71613.0        0         0       26       426         49              127
# 3  26646.0        1         0       26        11          4               20
# 4  58293.0        1         0       94       173         43              118
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  ...  marital_Together  \
# 0              172                88            88  ...                 0
# 1                2                 1             6  ...                 0
# 2              111                21            42  ...                 1
# 3               10                 3             5  ...                 1
# 4               46                27            15  ...                 0
#
# ...

# %%
data.columns
# Out:
# Index(['Income', 'Kidhome', 'Teenhome', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response',
#        'Age', 'Customer_Days', 'marital_Divorced', 'marital_Married',
#        'marital_Single', 'marital_Together', 'marital_Widow',
#        'education_2n Cycle', 'education_Basic', 'education_Graduation',
#        'education_Master', 'education_PhD', 'MntTotal', 'MntRegularProds',
#        'AcceptedCmpOverall'],
#       dtype='object')

# %%
data.describe()
# Out:
#               Income      Kidhome     Teenhome      Recency     MntWines  \
# count    2205.000000  2205.000000  2205.000000  2205.000000  2205.000000
# mean    51622.094785     0.442177     0.506576    49.009070   306.164626
# std     20713.063826     0.537132     0.544380    28.932111   337.493839
# min      1730.000000     0.000000     0.000000     0.000000     0.000000
# 25%     35196.000000     0.000000     0.000000    24.000000    24.000000
# 50%     51287.000000     0.000000     0.000000    49.000000   178.000000
# 75%     68281.000000     1.000000     1.000000    74.000000   507.000000
# max    113734.000000     2.000000     2.000000    99.000000  1493.000000
#
#          MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# count  2205.000000      2205.000000      2205.000000       2205.000000
# mean     26.403175       165.312018        37.756463         27.128345
# std      39.784484       217.784507        54.824635         41.130468
# ...

# %%
data.dtypes
# Out:
# Income                  float64
# Kidhome                   int64
# Teenhome                  int64
# Recency                   int64
# MntWines                  int64
# MntFruits                 int64
# MntMeatProducts           int64
# MntFishProducts           int64
# MntSweetProducts          int64
# MntGoldProds              int64
# NumDealsPurchases         int64
# NumWebPurchases           int64
# NumCatalogPurchases       int64
# NumStorePurchases         int64
# NumWebVisitsMonth         int64
# AcceptedCmp3              int64
# AcceptedCmp4              int64
# AcceptedCmp5              int64
# AcceptedCmp1              int64
# AcceptedCmp2              int64
# Complain                  int64
# Z_CostContact             int64
# Z_Revenue                 int64
# Response                  int64
# Age                       int64
# Customer_Days             int64
# marital_Divorced          int64
# marital_Married           int64
# marital_Single            int64
# ...

# %%
data.shape
# Out:
# (2205, 39)

# %%
data['children']=data['Teenhome'] + data['Kidhome']
data.head()
# Out:
#     Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0  58138.0        0         0       58       635         88              546
# 1  46344.0        1         1       38        11          1                6
# 2  71613.0        0         0       26       426         49              127
# 3  26646.0        1         0       26        11          4               20
# 4  58293.0        1         0       94       173         43              118
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  ...  marital_Widow  \
# 0              172                88            88  ...              0
# 1                2                 1             6  ...              0
# 2              111                21            42  ...              0
# 3               10                 3             5  ...              0
# 4               46                27            15  ...              0
#
#    education_2n Cycle  education_Basic  education_Graduation  \
# ...

# %%
data.children.value_counts()
# Out:
# children
# 1    1112
# 0     628
# 2     415
# 3      50
# Name: count, dtype: int64

# %%
# prompt: bar graph of number of children against counts

import matplotlib.pyplot as plt

data.children.value_counts().plot(kind='bar')
plt.xlabel("Number of Children")
plt.ylabel("Counts")
plt.title("Bar Graph of Number of Children vs Counts")
plt.show()

# %%
# prompt: bar graph of number of children against mean  house hold income

import matplotlib.pyplot as plt

# Calculate the mean household income for each number of children
mean_income_by_children = data.groupby('children')['Income'].mean()

# Create the bar graph
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
plt.bar(mean_income_by_children.index, mean_income_by_children.values)
plt.xlabel("Number of Children")
plt.ylabel("Mean Household Income")
plt.title("Bar Graph of Number of Children vs Mean Household Income")
plt.xticks(mean_income_by_children.index)  # Ensure all x-axis labels are shown
plt.show()

# %%
# Calculate the mean household income for each number of children
mean_sweet_by_children = data.groupby('children')['NumWebVisitsMonth'].mean()

# Create the bar graph
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
plt.bar(mean_sweet_by_children.index, mean_sweet_by_children.values)
plt.xlabel("Number of Children")
plt.ylabel("Mean Sweet consumed")
plt.title("Bar Graph of Number of Children vs Mean Income spent on sweeet")
plt.xticks(mean_sweet_by_children.index)  # Ensure all x-axis labels are shown
plt.show()

# %%
data['Education'] = data['education_2n Cycle'] + data['education_Basic'] + data['education_Graduation'] + data['education_Master'] + data['education_PhD']
data.head()
# Out:
#     Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0  58138.0        0         0       58       635         88              546
# 1  46344.0        1         1       38        11          1                6
# 2  71613.0        0         0       26       426         49              127
# 3  26646.0        1         0       26        11          4               20
# 4  58293.0        1         0       94       173         43              118
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  ...  education_2n Cycle  \
# 0              172                88            88  ...                   0
# 1                2                 1             6  ...                   0
# 2              111                21            42  ...                   0
# 3               10                 3             5  ...                   0
# 4               46                27            15  ...                   0
#
# ...

# %%
data.Education.value_counts()
# Out:
# Education
# 1    2205
# Name: count, dtype: int64

# %%
# prompt: group bar graph of number of childen  with individual level of education [data['education_2n Cycle'] , data['education_Basic'] , data['education_Graduation'], data['education_Master'] , data['education_PhD']]counts

import matplotlib.pyplot as plt

# Assuming 'data' DataFrame is already loaded and processed as in your provided code

education_columns = ['education_2n Cycle', 'education_Basic', 'education_Graduation', 'education_Master', 'education_PhD']
education_counts = data[education_columns].sum()

plt.figure(figsize=(10, 6))
plt.bar(education_counts.index, education_counts.values)
plt.xlabel("Education Level")
plt.ylabel("Counts")
plt.title("Grouped Bar Graph of Education Levels")
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.show()

# %%
# prompt: group bar graph of number of childen  with individual level of education [data['education_2n Cycle'] , data['education_Basic'] , data['education_Graduation'], data['education_Master'] , data['education_PhD']] counts. use imbern

import matplotlib.pyplot as plt

# Assuming 'data' DataFrame and 'education_columns' are defined as in your previous code

children_by_education = data.groupby('children')[education_columns].sum()

# Transpose the DataFrame for easier plotting
children_by_education = children_by_education.T

ax = children_by_education.plot(kind='bar', figsize=(10, 6))

plt.xlabel("Education Level")
plt.ylabel("Number of Children")
plt.title("Number of Children by Education Level")
plt.xticks(rotation=45, ha='right')
plt.legend(title='Number of Children')
plt.tight_layout()
plt.show()

# %%
# prompt: group bar graph of number of childen  with individual level of education [data['education_2n Cycle'] , data['education_Basic'] , data['education_Graduation'], data['education_Master'] , data['education_PhD']] counts. use imbean library instead of matplotlib

# Assuming 'data' DataFrame and 'education_columns' are defined as in your previous code
import pandas as pd
import plotly.express as px

education_columns = ['education_2n Cycle', 'education_Basic', 'education_Graduation', 'education_Master', 'education_PhD']
children_by_education = data.groupby('children')[education_columns].sum()

# Transpose the DataFrame for easier plotting with plotly
children_by_education = children_by_education.T.reset_index()

# Melt the DataFrame for plotting
children_by_education = children_by_education.melt(id_vars='index', var_name='Number of Children', value_name='Count')

# Rename the 'index' column for better readability in the plot
children_by_education = children_by_education.rename(columns={'index': 'Education Level'})


fig = px.bar(children_by_education, x='Education Level', y='Count', color='Number of Children', barmode='group',
             labels={'Count': 'Number of Children'},
             title='Number of Children by Education Level')
fig.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# ... (your existing code)
mnt_columns = ['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']
# Create a consolidated Education column
data['Education'] = data[education_columns].idxmax(axis=1)

# Group by education level and calculate the mean of Mnt columns
mnt_by_education0 = data.groupby('Education')[mnt_columns].mean()

# ... (rest of your plotting code)
# Transpose the DataFrame for easier plotting with plotly
mnt_by_education1 = mnt_by_education0.T.reset_index()

# Melt the DataFrame for plotting
mnt_by_education2 = mnt_by_education1.melt(id_vars='index', var_name='Education Level', value_name='Mean Amount Spent')

# Rename the 'index' column for better readability in the plot
mnt_by_education = mnt_by_education2.rename(columns={'index': 'Product Category'})


fig = px.bar(mnt_by_education, x='Education Level', y='Mean Amount Spent', color='Product Category', barmode='group',
             labels={'Mean Amount Spent': 'Mean Amount Spent'},
             title='Mean Amount Spent on Product Categories by Education Level')
fig.show()

# %%
status = ['marital_Divorced', 'marital_Married', 'marital_Single', 'marital_Together', 'marital_Widow']
# Create a consolidated status column
data['status'] = data[status].idxmax(axis=1)

# Group by marital status and calculate the mean of Mnt columns
mnt_by_education0 = data.groupby('status')[mnt_columns].mean()

# Transpose the DataFrame for easier plotting with plotly
mnt_by_education1 = mnt_by_education0.T.reset_index()

# Melt the DataFrame for plotting
mnt_by_education2 = mnt_by_education1.melt(id_vars='index', var_name='Marital Status', value_name='Mean Amount Spent')

# Rename the 'index' column for better readability in the plot
mnt_by_education = mnt_by_education2.rename(columns={'index': 'Product Category'})

# Plotting with Plotly
fig = px.bar(mnt_by_education, x='Marital Status', y='Mean Amount Spent', color='Product Category', barmode='group',
             labels={'Mean Amount Spent': 'Mean Amount Spent'},
             title='Mean Amount Spent on Product Categories by Marital Status')
fig.show()

# %%
mnt_by_education
# Out:
#     Product Category    Marital Status  Mean Amount Spent
# 0           MntWines  marital_Divorced         327.600000
# 1          MntFruits  marital_Divorced          27.634783
# 2    MntMeatProducts  marital_Divorced         151.473913
# 3    MntFishProducts  marital_Divorced          35.313043
# 4   MntSweetProducts  marital_Divorced          27.030435
# 5       MntGoldProds  marital_Divorced          46.578261
# 6           MntWines   marital_Married         300.818501
# 7          MntFruits   marital_Married          25.716628
# 8    MntMeatProducts   marital_Married         157.707260
# 9    MntFishProducts   marital_Married          35.569087
# 10  MntSweetProducts   marital_Married          26.838407
# 11      MntGoldProds   marital_Married          42.989461
# 12          MntWines    marital_Single         291.651992
# 13         MntFruits    marital_Single          27.310273
# 14   MntMeatProducts    marital_Single         184.199161
# ...

# %%
number = ['NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth']
#data= data[number]
status = ['marital_Divorced', 'marital_Married', 'marital_Single', 'marital_Together', 'marital_Widow']
# Create a consolidated status column
data['status'] = data[status].idxmax(axis=1)

# Group by marital status and calculate the mean of Mnt columns
mnt_by_education0 = data.groupby('status')[number].mean()

# Transpose the DataFrame for easier plotting with plotly
mnt_by_education1 = mnt_by_education0.T.reset_index()

# Melt the DataFrame for plotting
mnt_by_education2 = mnt_by_education1.melt(id_vars='index', var_name='Marital Status', value_name='Number of purchases')

# Rename the 'index' column for better readability in the plot
mnt_by_education = mnt_by_education2.rename(columns={'index': 'Purchases'})

# Plotting with Plotly
fig = px.bar(mnt_by_education, x='Marital Status', y='Number of purchases', color='Purchases', barmode='group',
             labels={'Mean purchases': 'Mean Purchases'},
             title='Mean Amount Spent on Product Categories by Marital Status')
fig.show()

# %%
# prompt: Utilize clustering algorithms

from sklearn.cluster import KMeans
import numpy as np

# Select features for clustering (example features)
features = ['Income', 'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']
X = data[features]

# Scale the features (important for KMeans)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Determine optimal number of clusters (e.g., using the elbow method)
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# Apply KMeans clustering with the chosen number of clusters (e.g., 3)
optimal_k = 3 #Based on the Elbow Method, change this value if needed
kmeans = KMeans(n_clusters=optimal_k, init='k-means++', max_iter=300, n_init=10, random_state=0)
data['cluster'] = kmeans.fit_predict(X_scaled)

# Analyze the clusters
print(data.groupby('cluster').agg({
    'Income': 'mean',
    'Recency': 'mean',
    'MntWines': 'mean',
    'MntFruits': 'mean',
    'MntMeatProducts': 'mean',
    'MntFishProducts': 'mean',
    'MntSweetProducts': 'mean',
    'MntGoldProds': 'mean'
}))

# Visualize the clusters (example with two features)
plt.scatter(data['Income'], data['MntWines'], c=data['cluster'], cmap='viridis')
plt.xlabel('Income')
plt.ylabel('Spending on Wine')
plt.title('Customer Segmentation')
plt.show()
# Out:
#                Income    Recency    MntWines  MntFruits  MntMeatProducts  \
# cluster
# 0        74880.962441  49.417840  565.863850  85.265258       466.948357
# 1        65857.490435  49.173913  597.669565  26.182609       223.008696
# 2        36594.162791  48.785714   75.062292   5.681894        31.032392
#
#          MntFishProducts  MntSweetProducts  MntGoldProds
# cluster
# 0             119.176056         86.814554     84.429577
# 1              38.650435         27.360000     68.443478
# 2               8.521595          5.899502     18.126246

# %%
X.head()
# Out:
#     Income  Recency  MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# 0  58138.0       58       635         88              546              172
# 1  46344.0       38        11          1                6                2
# 2  71613.0       26       426         49              127              111
# 3  26646.0       26        11          4               20               10
# 4  58293.0       94       173         43              118               46
#
#    MntSweetProducts  MntGoldProds
# 0                88            88
# 1                 1             6
# 2                21            42
# 3                 3             5
# 4                27            15

# %%
pd.set_option("display.max_rows", None)

X_scaled
# Out:
# array([[ 0.31465086,  0.31083003,  0.97456584, ...,  2.44915427,
#          1.48030077,  0.84955631],
#        [-0.25487741, -0.38060021, -0.8747762 , ..., -0.65234495,
#         -0.63539933, -0.73576658],
#        [ 0.96535404, -0.79545835,  0.3551548 , ...,  1.33626338,
#         -0.14903149, -0.03977117],
#        ...,
#        [ 0.25877972,  1.45168993,  1.78365298, ..., -0.10502155,
#         -0.36789702, -0.38776888],
#        [ 0.85100412, -1.41774556,  0.36108218, ...,  0.77069587,
#          0.06983404,  0.32755975],
#        [ 0.06021263, -0.31145718, -0.6584269 , ..., -0.65234495,
#         -0.63539933, -0.44576849]])

# %%
wcss
# Out:
# [17640.0,
#  10662.431126783875,
#  9183.789354701456,
#  8221.359161892673,
#  7567.975979080113,
#  7051.9508157285245,
#  6629.97928430719,
#  6308.65523536283,
#  6028.455652648827,
#  5777.226779356219]

# %%
# prompt: Calculate key metrics such as average purchase value, frequency of
# purchases, etc.

# Calculate average purchase value
data['Total_Spending'] = data[mnt_columns].sum(axis=1)
average_purchase_value = data['Total_Spending'].mean()
print(f"Average Purchase Value: {average_purchase_value}")

# Calculate purchase frequency (assuming 'TotalPurchases' is the total number of purchases across all categories)
data['TotalPurchases'] = data[['NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases']].sum(axis=1)
purchase_frequency = data['TotalPurchases'].mean()
print(f"Purchase Frequency: {purchase_frequency}")

# You can further segment these metrics by different customer groups (e.g., education level, marital status, etc.) as you've already done.
# Example: Average purchase value by education level
average_purchase_by_education = data.groupby('Education')['Total_Spending'].mean()
print("\nAverage Purchase Value by Education Level:\n", average_purchase_by_education)

# Example: Purchase frequency by marital status
purchase_frequency_by_status = data.groupby('status')['TotalPurchases'].mean()
print("\nPurchase Frequency by Marital Status:\n", purchase_frequency_by_status)
# Out:
# Average Purchase Value: 606.821768707483
# Purchase Frequency: 14.88798185941043
#
# Average Purchase Value by Education Level:
#  Education
# education_2n Cycle      499.489899
# education_Basic          81.796296
# education_Graduation    621.746631
# education_Master        611.280220
# education_PhD           672.722689
# Name: Total_Spending, dtype: float64
#
# Purchase Frequency by Marital Status:
#  status
# marital_Divorced    15.343478
# marital_Married     14.905152
# marital_Single      14.350105
# marital_Together    14.896127
# marital_Widow       16.631579
# Name: TotalPurchases, dtype: float64

# %%
data.describe()
# Out:
#               Income      Kidhome     Teenhome      Recency     MntWines  \
# count    2205.000000  2205.000000  2205.000000  2205.000000  2205.000000
# mean    51622.094785     0.442177     0.506576    49.009070   306.164626
# std     20713.063826     0.537132     0.544380    28.932111   337.493839
# min      1730.000000     0.000000     0.000000     0.000000     0.000000
# 25%     35196.000000     0.000000     0.000000    24.000000    24.000000
# 50%     51287.000000     0.000000     0.000000    49.000000   178.000000
# 75%     68281.000000     1.000000     1.000000    74.000000   507.000000
# max    113734.000000     2.000000     2.000000    99.000000  1493.000000
#
#          MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# count  2205.000000      2205.000000      2205.000000       2205.000000
# mean     26.403175       165.312018        37.756463         27.128345
# std      39.784484       217.784507        54.824635         41.130468
# ...

# %%
# prompt:  Utilize clustering algorithms (e.g., K-means) to segment
# customers based on behavior and purchase patterns.

# ... (your existing code)

# Select features for clustering (example features)
features = ['Income', 'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']
X = data[features]

# Scale the features (important for KMeans)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Determine optimal number of clusters (e.g., using the elbow method)
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# Apply KMeans clustering with the chosen number of clusters (e.g., 3)
optimal_k = 3  # Based on the Elbow Method, change this value if needed
kmeans = KMeans(n_clusters=optimal_k, init='k-means++', max_iter=300, n_init=10, random_state=0)
data['cluster'] = kmeans.fit_predict(X_scaled)

# Analyze the clusters
cluster_analysis = data.groupby('cluster').agg({
    'Income': 'mean',
    'Recency': 'mean',
    'MntWines': 'mean',
    'MntFruits': 'mean',
    'MntMeatProducts': 'mean',
    'MntFishProducts': 'mean',
    'MntSweetProducts': 'mean',
    'MntGoldProds': 'mean'
})
print(cluster_analysis)
# Out:
#                Income    Recency    MntWines  MntFruits  MntMeatProducts  \
# cluster
# 0        74880.962441  49.417840  565.863850  85.265258       466.948357
# 1        65857.490435  49.173913  597.669565  26.182609       223.008696
# 2        36594.162791  48.785714   75.062292   5.681894        31.032392
#
#          MntFishProducts  MntSweetProducts  MntGoldProds
# cluster
# 0             119.176056         86.814554     84.429577
# 1              38.650435         27.360000     68.443478
# 2               8.521595          5.899502     18.126246

# %%
# prompt: Utilize clustering algorithms (e.g., K-means) to segment
# customers based on behavior and purchase patterns

# Visualize the clusters using a 3D scatter plot (example with three features)
import plotly.graph_objects as go

fig = go.Figure(data=[go.Scatter3d(
    x=data['Income'],
    y=data['MntWines'],
    z=data['MntMeatProducts'],
    mode='markers',
    marker=dict(
        size=5,
        color=data['cluster'],  # Set marker color to cluster labels
        opacity=0.8
    )
)])

fig.update_layout(
    title='Customer Segmentation (3D)',
    scene=dict(
        xaxis_title='Income',
        yaxis_title='Spending on Wine',
        zaxis_title='Spending on Meat Products'
    )
)
fig.show()

# %%
import plotly.graph_objects as go

# Create a 2D scatter plot
fig = go.Figure(data=[go.Scatter(
    x=data['Income'],
    y=data['MntWines'],
    mode='markers',
    marker=dict(
        size=5,
        color=data['cluster'],  # Set marker color to cluster labels
        opacity=0.8
    )
)])

# Update layout with axis titles and a plot title
fig.update_layout(
    title='Customer Segmentation (2D)',
    xaxis_title='Income',
    yaxis_title='Spending on Wine'
)

# Show the plot
fig.show()
