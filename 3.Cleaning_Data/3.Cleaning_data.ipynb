# %%
import pandas as pd
data = pd.read_csv('AB_NYC_2019.csv')
data.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
data.shape
# Out:
# (48895, 16)

# %%
data.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
# Counting NaN values in a specific columns
for col in data.columns:
  nan_count = data[col].isna().sum()
  print(f'{col}: {nan_count}')
# Out:
# id: 0
# name: 16
# host_id: 0
# host_name: 21
# neighbourhood_group: 0
# neighbourhood: 0
# latitude: 0
# longitude: 0
# room_type: 0
# price: 0
# minimum_nights: 0
# number_of_reviews: 0
# last_review: 10052
# reviews_per_month: 10052
# calculated_host_listings_count: 0
# availability_365: 0

# %%
data.minimum_nights.min()
# Out:
# 1

# %%
data= data.drop(data[data['number_of_reviews']==0].index, inplace=False)

# %%
data= data.dropna(subset=['name', 'host_name'])
data.shape
# Out:
# (38821, 16)

# %%
for col in data.columns:
  nan_count = data[col].isna().sum()
  print(f'{col}: {nan_count}')
# Out:
# id: 0
# name: 0
# host_id: 0
# host_name: 0
# neighbourhood_group: 0
# neighbourhood: 0
# latitude: 0
# longitude: 0
# room_type: 0
# price: 0
# minimum_nights: 0
# number_of_reviews: 0
# last_review: 0
# reviews_per_month: 0
# calculated_host_listings_count: 0
# availability_365: 0

# %%
data.name.values[0:10]
# Out:
# array(['Clean & quiet apt home by the park', 'Skylit Midtown Castle',
#        'Cozy Entire Floor of Brownstone',
#        'Entire Apt: Spacious Studio/Loft by central park',
#        'Large Cozy 1 BR Apartment In Midtown East', 'BlissArtsSpace!',
#        "Large Furnished Room Near B'way ",
#        'Cozy Clean Guest Room - Family Apt',
#        'Cute & Cozy Lower East Side 1 bdrm',
#        'Beautiful 1br on Upper West Side'], dtype=object)

# %%
data.minimum_nights.mean()
# Out:
# 5.869220267381056

# %%
column_to_sort = 'price'
top_10_values = data.sort_values(by=column_to_sort, ascending=False).head(10)
top_10_values
# Out:
#              id                                               name    host_id  \
# 9151    7003697                Furnished room in Astoria apartment   20582832
# 17692  13894339    Luxury 1 bedroom apt. -stunning Manhattan views    5143901
# 12342   9528920                Quiet, Clean, Lit @ LES & Chinatown    3906464
# 6530    4737930                                 Spanish Harlem Apt    1235070
# 30268  23377410  Beautiful/Spacious 1 bed luxury flat-TriBeCa/Soho   18128455
# 4377    2953058                                      Film Location    1177497
# 45666  34895693                               Gem of east Flatbush  262534951
# 3537    2110145                 UWS 1BR w/backyard + block from CP    2151325
# 43009  33397385    Midtown Manhattan great location (Gramacy park)   16105313
# 26739  21238053                                         Broadway 1  153497815
#
#          host_name neighbourhood_group       neighbourhood  latitude  \
# ...

# %%
data.availability_365.max()
# Out:
# 365

# %%
sca = ['price','minimum_nights', 'number_of_reviews',
       'reviews_per_month', 'calculated_host_listings_count',
       ]
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data[sca])
data[sca] = scaled_data
data.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
# 5        Chris           Manhattan   Murray Hill  40.74767  -73.97500
#
#          room_type     price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
def encode_labels(df, columns):
  from sklearn.preprocessing import LabelEncoder
  le = LabelEncoder()
  for col in columns:
    data[col] = le.fit_transform(data[col])
  return data

# %%
colu=['name', 'host_name', 'neighbourhood_group',
       'neighbourhood', 'room_type']
encode_labels(data,colu)
# Out:
#              id   name    host_id  host_name  neighbourhood_group  \
# 0          2539   9933       2787       4303                    1
# 1          2595  30014       2845       4120                    2
# 3          3831  11945       4869       5363                    1
# 4          5022  15102       7192       5114                    2
# 5          5099  19649       7322       1666                    2
# ...         ...    ...        ...        ...                  ...
# 48782  36425863  20991   83554966       7780                    2
# 48790  36427429  24596  257683179       3620                    3
# 48799  36438336  29701  211644523       1044                    4
# 48805  36442252   1017  273841667       1134                    0
# 48852  36455809  12223   74162901       1694                    1
#
#        neighbourhood  latitude  longitude  room_type     price  \
# 0                107  40.64749  -73.97237          1  0.033846
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['Month'] = pd.to_datetime(data['last_review']).dt.month
data['Year'] = pd.to_datetime(data['last_review']).dt.year
data['Day'] = pd.to_datetime(data['last_review']).dt.day
data= data.drop('last_review', axis=1)

# %%
sca1=['name', 'host_name', 'neighbourhood_group',
       'neighbourhood', 'room_type','availability_365', 'Year']
from sklearn.preprocessing import MinMaxScaler
scaler1 = MinMaxScaler()
scaled_data = scaler1.fit_transform(data[sca1])
data[sca1] = scaled_data
data.head()
# Out:
#      id      name  host_id  host_name  neighbourhood_group  neighbourhood  \
# 0  2539  0.259673     2787   0.435350                 0.25       0.493088
# 1  2595  0.784639     2845   0.416835                 0.50       0.580645
# 3  3831  0.312271     4869   0.542594                 0.25       0.188940
# 4  5022  0.394803     7192   0.517402                 0.50       0.281106
# 5  5099  0.513672     7322   0.168555                 0.50       0.626728
#
#    latitude  longitude  room_type     price  minimum_nights  \
# 0  40.64749  -73.97237        0.5  0.033846       -0.280020
# 1  40.75362  -73.98377        0.0  0.419648       -0.280020
# 3  40.68514  -73.95976        0.0 -0.270734       -0.280020
# 4  40.79851  -73.94399        0.0 -0.316421        0.237554
# 5  40.74767  -73.97500        0.0  0.292740       -0.165004
#
#    number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 0          -0.421114          -0.692272                        0.031685
# ...
